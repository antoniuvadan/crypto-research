# %%
import polars as pl
from pathlib import Path

book_ticker_path = Path("data/BTCUSD_PERP-bookTicker")

df_book_ticker = pl.scan_parquet(book_ticker_path / "*.parquet")
df_book_ticker.collect_schema().names()
